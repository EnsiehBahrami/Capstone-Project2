# %% [markdown]
# ## Commercial Daily Usge

# %% [markdown]
# ###  1) stationary at 5% significance level
# **Results of Dickey-Fuller Test:**
#
# test statistic        -3.251336
#
# p-value                0.017199
#
# Critical Value 1%     -3.639224
#
# Critical Value 5%     -2.951230
#
# Critical Value 10%    -2.614447

# %% [markdown]
# ### 2) There is no special trend
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3) Daily usage doesn't follow seasonality
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4) Daily usage is not a white noise, because:
# * Mean and variance are not constant over time, and,
# * Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero),
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5) Daily Usge - Difference order 1: stationary at all significance levels
# **KPSS Test Result:**
#
# Test Statistic           0.102324
#
# p-value                  0.100000
#
# Lags Used                6.000000
#
# Critical Value (10%)     0.347000
#
# Critical Value (5%)      0.463000
#
# Critical Value (2.5%)    0.574000
#
# Critical Value (1%)      0.739000
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6) Performance of Univariant Time Series Forecasting Models:
# #### The Best model to forecast Commercial usage is Simple Exponential Smoothing with smoothing factor of 0.73
#
#  * Model: Simple Exponential Smoothing
#  * α: 0.73
#  * RMSE: 0.157
#  * MAE: 0.13
#  * MAPE: 10.6
#  * R2: 0.23

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -------

# %% [markdown]
# ## Industrial Daily Usge

# %% [markdown]
# ## 1) stationary at 5% significance level
#
# **Results of Dickey-Fuller Test:**
#
# test statistic        -3.491720
#
# p-value                0.008202
#
# #Lags Used            0.000000
#
# #Observation Used     34.000000
#
# Critical Value 1%     -3.639224
#
# Critical Value 5%     -2.951230
#
# Critical Value 10%    -2.614447

# %% [markdown]
# ## 2) There is no spacial trend
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Daily usage follow seasonality
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Daily usage is not a white noise, because:
# Mean and variance are not constant over time,
# Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5) Industrial Daily Usge - Difference order 1: stationary at all significance levels
#
# **KPSS Test Result:**
#
# Test Statistic           0.090953
#
# p-value                  0.100000
#
# Lags Used                6.000000
#
# Critical Value (10%)     0.347000
#
# Critical Value (5%)      0.463000
#
# Critical Value (2.5%)    0.574000
#
# Critical Value (1%)      0.739000
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6) Performance of Univariant Time Series Forecasting Models:
# ### The Best model to forecast Industrial usage is ARMA(1,1)
#
# * Model: AutoRegressive Moving Average
# * min_AIC: 22.09
# * (p,q): (1, 1)
# * RMSE: 0.145
# * MAE: 0.116
# * MAPE: 292.34
# * R2: 0.26

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----

# %% [markdown]
# ## Irrigation Group

# %% [markdown]
# ## 1) Stationary at 5% significance level
#
# **Results of Dickey-Fuller Test:**
#
# test statistic        -3.353235
#
# p-value                0.012660
#
# #Lags Used             1.000000
#
# #Observation Used     33.000000
#
# Critical Value 1%     -3.646135
#
# Critical Value 5%     -2.954127
#
# Critical Value 10%    -2.615968

# %% [markdown]
# ## 2) There is no trend
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Daily usage follows seasonality
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Daily usage is not a white noise, because:
# * Mean and variance are not constant over time,
#
# * Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero)
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5) Irrigation Daily Usge - Difference order 1: stationary at all significance levels
#
# **KPSS Test Result:**
#
# Test Statistic           0.050217
#
# p-value                  0.100000
#
# Lags Used                0.000000
#
# Critical Value (10%)     0.347000
#
# Critical Value (5%)      0.463000
#
# Critical Value (2.5%)    0.574000
#
# Critical Value (1%)      0.739000
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6) Performance of Univariant Time Series Forecasting Models:
#
# #### The Best model to forecast Irrigation usage is SARIMAX
#
# * Model: SARIMA
# * min_AIC: -38.65
# * trend: c
# * (p,d,q): (1, 0, 0)
# * (P,D,Q,m): (1, 0, 2, 12), min_AIC: -38.65
# * RMSE: 0.458
# * MAE: 0.419
# * MAPE: 1584.98
# * R2: 0.77

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ------

# %% [markdown]
# ##  Duplex Group

# %% [markdown]
# ### 1) Daily usage stationary at 10% significance level
#
# **Results of Dickey-Fuller Test:**
#
# test statistic        -2.897859
#
# p-value                0.045598
#
# #Lags Used            1.000000
#
# #Observation Used    33.000000
#
# Critical Value 1%     -3.646135
#
# Critical Value 5%     -2.954127
#
# Critical Value 10%    -2.615968

# %% [markdown]
# ## 2) There is no special trend
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Daily usage doesn't follow seasonality
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Daily usage is not a white noise, because:
# * Mean and variance are not constant over time,
#
# * Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5) Duplex Daily Usge - Difference order 1: stationary at all significance levels
#
# **KPSS Test Result:**
#
# Test Statistic           0.0521
#
# p-va
# lue                  0.1000
#
# Lags Used                2.0000
#
# Critical Value (10%)     0.3470
#
# Critical Value (5%)      0.4630
#
# Critical Value (2.5%)    0.5740
#
# Critical Value (1%)      0.7390
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6) Performance of Univariant Time Series Forecasting Models:
#
# #### The Best model to forecast Duplex usage is SARIMAX
#
# * Model: SARIMA
# * min_AIC: -38.65
# * trend: c
# * (p,d,q): (1, 0, 0)
# * (P,D,Q,m): (1, 0, 2, 12)
# * RMSE: 0.458
# * MAE: 0.419
# * MAPE: 1584.98
# * R2: 0.77

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----

# %% [markdown]
# ## Single Family

# %% [markdown]
# ## 1) Daily usage is not stationary at any significance level
#
# **Results of Dickey-Fuller Test:**
#
# test statistic        -2.337469
#
# p-value                0.160168
#
# #Lags Used            0.000000
#
# #Observation Used    34.000000
#
# Critical Value 1%     -3.639224
#
# Critical Value 5%     -2.951230
#
# Critical Value 10%    -2.614447

# %% [markdown]
# ## 2) There is no trend
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Daily usage doesn't follow seasonality
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Daily usage is not a white noise, because:
# * Mean and variance are not constant over time,
#
# * Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5) Single-Family Daily Usge - Difference order 1: stationary at all significance levels
#
# **KPSS Test Result:**
#
# Test Statistic           0.069848
#
# p-value                  0.100000
#
# Lags Used                2.000000
#
# Critical Value (10%)     0.347000
#
# Critical Value (5%)      0.463000
#
# Critical Value (2.5%)    0.574000
#
# Critical Value (1%)      0.739000
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6) Performance of Univariant Time Series Forecasting Models:
#
# #### The Best model to forecast single family usage is Simple Exponential Smoothing with smoothing factor of .85
#
# * Model: Simple Exponential Smoothing
# * alpha = 0.85
# * RMSE: 0.018
# * MAE: 0.014
# * MAPE: 8.92
# * R2: 0.67

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# -----------

# %% [markdown]
# ## Multi Family

# %% [markdown]
# ## 1) Daily usage is not stationary at any significance level
#
#
#
# **Results of Dickey-Fuller Test:**
#
# test statistic        -1.931992
#
# p-value                0.317164
#
# #Lags Used            0.000000
#
# #Observation Used    34.000000
#
# Critical Value 1%     -3.639224
#
# Critical Value 5%     -2.951230
#
# Critical Value 10%    -2.614447

# %% [markdown]
# ## 2) There is no trend
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3) Daily usage doesn't follow seasonality
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4) Daily usage is not a white noise, because:
# * Mean and variance are not constant over time,
#
# * Daily usage values are not independent, they are correlated with many values in the latter months (Autocorrelation at many lags are not zero)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5)
# #### The Best model to forecast Multi family is Simple Exponential Smoothing with smoothing factor of .85
#
# * Model: Simple Exponential Smoothing
# * alpha = 1
# * RMSE: 0.002
# * MAE: 0.002
# * MAPE: 8.213
# * R2: 0.85

# %% [markdown]
# ![image.png](attachment:image.png)
